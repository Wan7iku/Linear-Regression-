# %%
import pandas as pd
import numpy as np
from google.colab import drive

from pandas import read_csv

# Load the dataset
drive.mount('/content/drive')

df = pd.read_csv('/content/drive/My Drive/HeatingCost.csv')
# Out:
# Mounted at /content/drive

# %%
df.head()
# Out:
#    House  Heating Cost  Minimum Temperature  Insulation  Age  Windows
# 0      1           250                   35           3    6       10
# 1      2           360                   29           4   10        1
# 2      3           165                   36           7    3        9
# 3      4            43                   60           6    9        8
# 4      5            92                   65           5    6        8

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#pairplot of Heatin cost against Age
sns.pairplot(df, x_vars=['Age'], y_vars=['Heating Cost'])
plt.show()

# %%
# Save resulting DataFrame in a separate variable to prepare for regression
#data1 = df[["Age", "Heating Cost"]]
#data1.head()
# Out:
#    Age  Heating Cost
# 0    6           250
# 1   10           360
# 2    3           165
# 3    9            43
# 4    6            92

# %%
X=df[["Age"]]
Y = df[["Heating Cost"]]

# %%
from sklearn.linear_model import LinearRegression

# %%
model= LinearRegression()
model.fit(Age,Heating)
# Get results
slope = model.coef_[0]
intercept = model.intercept_
r_squared = model.score(X, Y)

print(f"Slope: {slope}")
print(f"Intercept: {intercept}")
print(f"R²: {r_squared}")
# Out:
# Slope: [17.00943396]
# Intercept: [86.18396226]
# R²: 0.2880764756384838

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create scatterplot with regression line
sns.regplot(x=df["Age"], y=df["Heating Cost"], line_kws={"color": "red"})

plt.title("Heating Cost vs Age with Regression Line")
plt.xlabel("Age")
plt.ylabel("Heating Cost")
plt.show()

# %% [markdown]
# Discussion
